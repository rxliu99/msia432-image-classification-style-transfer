# %% [markdown]
# # test for one image

# %%
from PIL import Image

def resize_image(input_image_path, output_image_path, target_size):
    # Open the image
    image = Image.open(input_image_path)

    # Resize the image
    resized_image = image.resize(target_size)

    # Save the resized image
    resized_image.save(output_image_path)

# Example usage
input_image_path = "/Users/Jerry/Desktop/deep learning/data/animals/animals/crab/2.jpg"
output_image_path = "resized_image.jpg"
target_size = (128,128)  # Specify the desired size (e.g., 224x224)

resize_image(input_image_path, output_image_path, target_size)

# %% [markdown]
# # crab

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/crab"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/crab"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # bear

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/bear"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/bear"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # cat

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/cat"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/cat"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # dog

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/dog"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/dog"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # dolphin

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/dolphin"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/dolphin"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # duck

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/duck"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/duck"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # hamster

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/hamster"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/hamster"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # jellyfish

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/jellyfish"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/jellyfish"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # leopard

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/leopard"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/leopard"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)

# %% [markdown]
# # panda

# %%
import os
from PIL import Image

def resize_images(input_folder, output_folder, target_size):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    file_list = os.listdir(input_folder)

    # Resize each image in the input folder
    for filename in file_list:
        # Construct the input and output file paths
        input_image_path = os.path.join(input_folder, filename)
        output_image_path = os.path.join(output_folder, filename)

        # Skip non-image files
        if not is_image_file(input_image_path):
            continue

        # Open the image
        image = Image.open(input_image_path)

        # Resize the image
        resized_image = image.resize(target_size)

        # Save the resized image
        resized_image.save(output_image_path)

def is_image_file(file_path):
    # Check if the file has an image extension
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif']
    extension = os.path.splitext(file_path)[1].lower()
    return extension in image_extensions

# Example usage
input_folder = "/Users/Jerry/Desktop/deep learning/data/animals/animals/panda"
output_folder = "/Users/Jerry/Desktop/deep learning/data/animals/resize/panda"
target_size = (128, 128)  # Specify the desired size (e.g., 224x224)

resize_images(input_folder, output_folder, target_size)
